# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# Basic DataFrame
#
# Consider the following Python dictionary data and Python list labels:

# %% [markdown]
# data = {'birds': ['Cranes', 'Cranes', 'plovers', 'spoonbills', 'spoonbills', 'Cranes', 'plovers', 'Cranes', 'spoonbills', 'spoonbills', 'Cranes'],
#         'age': [3.5, 4, 1.5, np.nan, 6, 3, 5.5, np.nan, 8, 4, 3.5], 'visits': [2, 4, 3, 4, 3, 4, 2, 2, 3, 2, 2],
#         'priority': ['yes', 'yes', 'no', np.nan, 'no', 'no', 'no', 'yes', 'no', 'no','yes']}

# %% [markdown]
# labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j', 'k']

# %%
data = {'birds': ['Cranes', 'Cranes', 'plovers', 'spoonbills', 'spoonbills', 'Cranes', 'plovers', 'Cranes', 'spoonbills', 'spoonbills', 'Cranes'], 
        'age': [3.5, 4, 1.5, np.nan, 6, 3, 5.5, np.nan, 8, 4, 3.5], 'visits': [2, 4, 3, 4, 3, 4, 2, 2, 3, 2, 2], 
        'priority': ['yes', 'yes', 'no', np.nan, 'no', 'no', 'no', 'yes', 'no', 'no','yes']}

labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j', 'k']

# %%
df = pd.DataFrame(data = data,index=labels)

# %%
df.columns
# Out:
# Index(['birds', 'age', 'visits', 'priority'], dtype='object')

# %% [markdown]
# Q-1:
# i. Create a DataFrame birds from the above dictionary data which has the index labels.
#
# ii. Display basic information about the dataFrame.
#
# iii. Show Alternate rows of the dataframe.

# %%
df.groupby('birds')['age'].sum()
# Out:
# birds
# Cranes        14.0
# plovers        7.0
# spoonbills    18.0
# Name: age, dtype: float64

# %%
#ii. Display basic information about the dataFrame.

df.describe()
# Out:
#             age     visits
# count  9.000000  11.000000
# mean   4.333333   2.818182
# std    1.903943   0.873863
# min    1.500000   2.000000
# 25%    3.500000   2.000000
# 50%    4.000000   3.000000
# 75%    5.500000   3.500000
# max    8.000000   4.000000

# %%
df.iloc[:-1]
# Out:
#         birds  age  visits priority
# a      Cranes  3.5       2      yes
# b      Cranes  4.0       4      yes
# c     plovers  1.5       3       no
# d  spoonbills  NaN       4      NaN
# e  spoonbills  6.0       3       no
# f      Cranes  3.0       4       no
# g     plovers  5.5       2       no
# h      Cranes  NaN       2      yes
# i  spoonbills  8.0       3       no
# j  spoonbills  4.0       2       no

# %%
d = """{
    "name":"shashi",
    "email id":"shashipolity@gmail.com",
    "tech":["DL","ML","CV"],
    "platforms":["Ineuron","TechNeuron","KidsNeuron"]
}"""

# %%
import json
res = json.loads(d)

# %%
pd.DataFrame(res)
# Out:
#      name                email id tech   platforms
# 0  shashi  shashipolity@gmail.com   DL     Ineuron
# 1  shashi  shashipolity@gmail.com   ML  TechNeuron
# 2  shashi  shashipolity@gmail.com   CV  KidsNeuron

# %%
df
# Out:
#         birds  age  visits priority
# a      Cranes  3.5       2      yes
# b      Cranes  4.0       4      yes
# c     plovers  1.5       3       no
# d  spoonbills  NaN       4      NaN
# e  spoonbills  6.0       3       no
# f      Cranes  3.0       4       no
# g     plovers  5.5       2       no
# h      Cranes  NaN       2      yes
# i  spoonbills  8.0       3       no
# j  spoonbills  4.0       2       no
# k      Cranes  3.5       2      yes

# %%
df.iloc[::2]
# Out:
#         birds  age  visits priority
# a      Cranes  3.5       2      yes
# c     plovers  1.5       3       no
# e  spoonbills  6.0       3       no
# g     plovers  5.5       2       no
# i  spoonbills  8.0       3       no
# k      Cranes  3.5       2      yes

# %% [markdown]
# Q-2:
# i. Show only rows [1st, 3rd, 7th] from columns ['bird', 'age']
#
# ii. Select rows where the number of visits is less than 4.

# %%
df[['birds','age']].iloc[[0,2,6]]
# Out:
#      birds  age
# a   Cranes  3.5
# c  plovers  1.5
# g  plovers  5.5

# %%
#ii. Select rows where the number of visits is less than 4.

#df[df['visits']<4]
df[df.visits<4]
# Out:
#         birds  age  visits priority
# a      Cranes  3.5       2      yes
# c     plovers  1.5       3       no
# e  spoonbills  6.0       3       no
# g     plovers  5.5       2       no
# h      Cranes  NaN       2      yes
# i  spoonbills  8.0       3       no
# j  spoonbills  4.0       2       no
# k      Cranes  3.5       2      yes

# %% [markdown]
# Q-3:
# i. Select all rows with nan values in age and visits column.
#
# ii. Fill nan with respective series mode value.

# %%
#i. Select all rows with nan values in age and visits column.

df[df.isnull().values]
# Out:
#         birds  age  visits priority
# d  spoonbills  NaN       4      NaN
# d  spoonbills  NaN       4      NaN
# h      Cranes  NaN       2      yes

# %%
df[df.age.isna() | df.visits.isna()]
# Out:
#         birds  age  visits priority
# d  spoonbills  NaN       4      NaN
# h      Cranes  NaN       2      yes

# %%
#ii. Fill nan with respective series mode value.

df.age.fillna(df.age.mode()[0],inplace=True)
df.visits.fillna(df.visits.mode()[0],inplace=True)

# %% [markdown]
# Q-4
#
# i. Find the total number of visits of the bird Cranes
#
# ii. Find the number of each type of birds in dataframe.
#
# iii. Print no of duplicate rows
#
# iv. Drop Duplicates rows and make this changes permanent. Show dataframe after changes.

# %%
df
# Out:
#         birds  age  visits priority
# a      Cranes  3.5       2      yes
# b      Cranes  4.0       4      yes
# c     plovers  1.5       3       no
# d  spoonbills  3.5       4      NaN
# e  spoonbills  6.0       3       no
# f      Cranes  3.0       4       no
# g     plovers  5.5       2       no
# h      Cranes  3.5       2      yes
# i  spoonbills  8.0       3       no
# j  spoonbills  4.0       2       no
# k      Cranes  3.5       2      yes

# %%
df[df['birds']=='Cranes'].visits.sum()
# Out:
# 14

# %% [markdown]
# ii. Find the number of each type of birds in dataframe.

# %%
df.birds.values
# Out:
# array(['Cranes', 'Cranes', 'plovers', 'spoonbills', 'spoonbills',
#        'Cranes', 'plovers', 'Cranes', 'spoonbills', 'spoonbills',
#        'Cranes'], dtype=object)

# %%
df.birds.value_counts()
# Out:
# Cranes        5
# spoonbills    4
# plovers       2
# Name: birds, dtype: int64

# %%
iii. Print no of duplicate rows
# Out:
#   Cell In[23], line 1
#     iii. Print no of duplicate rows
#                ^
# SyntaxError: invalid syntax

# %%
df.duplicated().sum()
# Out:
# 2

# %% [markdown]
# iv. Drop Duplicates rows and make this changes permanent. Show dataframe after changes.

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#         birds  age  visits priority
# a      Cranes  3.5       2      yes
# b      Cranes  4.0       4      yes
# c     plovers  1.5       3       no
# d  spoonbills  3.5       4      NaN
# e  spoonbills  6.0       3       no
# f      Cranes  3.0       4       no
# g     plovers  5.5       2       no
# i  spoonbills  8.0       3       no
# j  spoonbills  4.0       2       no

# %%
df1 = pd.read_csv('IPL_Matches_2008_2022.csv')

# %%
df1
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %% [markdown]
# Q-5: In IPL matches dataset some teams name has changed.
# You will have to consider them as same.

# %% [markdown]
# 'Delhi Capitals' formerly as 'Delhi Daredevils'
# 'Punjab Kings' formerly as 'Kings XI Punjab'
# 'Rising Pune Supergiant' formerly as 'Rising Pune Supergiants'

# %%
df1.columns
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2'],
#       dtype='object')

# %%
changed_name = {
    'Delhi Daredevils':'Delhi Capitals',
    'Kings XI Punjab':'Punjab Kings',
    'Rising Pune Supergiants':'Rising Pune Supergiant'
}

# %%
df1.replace(changed_name.keys(),changed_name.values(),inplace=True)

# %% [markdown]
# Q-6 Write a code which can display the bar chart of top 5 teams who have played maximum number of matches in the IPL.
#
# Hint: Be careful the data is divided in 2 different cols(Team 1 and Team 2)

# %%
(df1['Team1'].value_counts() + df1['Team2'].value_counts()).sort_values(ascending=False).head().plot(kind='bar')
# Out:
# <AxesSubplot: >

# %% [markdown]
# Q-7: Player who got Most no. of player of the match award playing against Mumbai Indians.

# %% [markdown]
# Just for this question assume player of the match award is given to players from winning team. Although this is true in most of the cases.

# %%
m1 = (df1.Team1 == 'Mumbai Indians') | (df1.Team2 == 'Mumbai Indians')

# %%
m2 = df1.WinningTeam != 'Mumbai Indians'

# %%
df1[m1 & m2].Player_of_Match.value_counts()
# Out:
# SPD Smith     4
# KL Rahul      4
# SK Raina      4
# JH Kallis     3
# CH Gayle      3
#              ..
# JJ Bumrah     1
# AJ Finch      1
# SS Iyer       1
# GJ Bailey     1
# MV Boucher    1
# Name: Player_of_Match, Length: 68, dtype: int64

# %% [markdown]
# Q-8: Team1 vs Team2 Dashbord
#
# Create a function which will take two string(name of two teams) as input. Show win Loss record between them and player getting most player of the match award in matches between these two teams.

# %%
def team1_vs_team2(t1,t2):
    m1 = (df1.Team1 == t1) | (df1.Team2 == t1)
    m2 = (df1.Team1 == t2) | (df1.Team2 == t2)
    dfs = df1[m1 & m2]
    print(dfs.WinningTeam.value_counts())
    print(dfs.Player_of_Match.value_counts().head(1))

team1_vs_team2('Mumbai Indians','Royal Challengers Bangalore')
# Out:
# Mumbai Indians                 17
# Royal Challengers Bangalore    13
# Name: WinningTeam, dtype: int64
# RG Sharma    4
# Name: Player_of_Match, dtype: int64

# %% [markdown]
# Q-9: Find out the top 7 cities where the matches of Kolkata Knight Riders are played frequently and plot the result as bar chart.
# .plot(kind = "bar") can help you to plot the bar chart. Also you can learn more about this method from here

# %%
df1.head(2)
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
#
#                          Team1             Team2  \
# 0             Rajasthan Royals    Gujarat Titans
# 1  Royal Challengers Bangalore  Rajasthan Royals
#
#                               Venue        TossWinner TossDecision SuperOver  \
# 0  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals          bat         N
# 1  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals        field         N
#
#         WinningTeam    WonBy  Margin method Player_of_Match  \
# 0    Gujarat Titans  Wickets     7.0    NaN       HH Pandya
# 1  Rajasthan Royals  Wickets     7.0    NaN      JC Buttler
#
#                                         Team1Players  \
# 0  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
#
# ...

# %%
df1[(df1.Team1 == 'Kolkata Knight Riders') | (df1.Team2 == 'Kolkata Knight Riders')].City.value_counts().head(7).plot(kind='bar')
# Out:
# <AxesSubplot: >

# %% [markdown]
# Q-10: Find out the average margin for the team Mumbai Indians for only the session 2011.

# %%
df1[((df1.Team1 == 'Mumbai Indians') | (df1.Team2 == 'Mumbai Indians')) & (df1.Season == "2011")]
# Out:
#          ID        City        Date Season        MatchNumber  \
# 703  501270     Chennai  2011-05-27   2011        Qualifier 2
# 704  501269      Mumbai  2011-05-25   2011  Elimination Final
# 706  501267     Kolkata  2011-05-22   2011                 70
# 710  501263      Mumbai  2011-05-20   2011                 66
# 718  501256      Mumbai  2011-05-14   2011                 59
# 722  501251  Chandigarh  2011-05-10   2011                 54
# 727  501246      Mumbai  2011-05-07   2011                 49
# 732  501241      Mumbai  2011-05-04   2011                 44
# 736  501237      Mumbai  2011-05-02   2011                 40
# 742  501231      Jaipur  2011-04-29   2011                 34
# 749  501224   Hyderabad  2011-04-24   2011                 27
# 752  501221      Mumbai  2011-04-22   2011                 25
# 754  501218      Mumbai  2011-04-20   2011                 21
# 762  501210      Mumbai  2011-04-15   2011                 13
# ...
